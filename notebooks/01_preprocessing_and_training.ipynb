# %% [markdown]
# # 01 — Data Preprocessing and Baseline Training
#
# Run the full pipeline:
#
# ```bash
# python run.py
# ```
#
# Outputs: `data/processed/processed_data.joblib`, `models/baseline_models.joblib`
