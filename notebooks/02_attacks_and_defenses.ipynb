# %% [markdown]
# # 02 — Adversarial Attacks and Defenses
#
# See `src/attacks.py`, `src/defenses.py`, and `results/metrics.json`.
#
# Defenses implemented: adversarial training, feature squeezing, ensemble.
